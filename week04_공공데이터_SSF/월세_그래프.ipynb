# %%
import pandas as pd
import matplotlib.pyplot as plt
import	platform
import	matplotlib.font_manager as	fm
import seaborn as sns

from linegraph_func import draw_line_one_graph

# %% [markdown]
# ### 월세

# %%
month_house=pd.read_excel('../data/연평균월세증가율.xlsx',index_col=0)
month_house.head()
# Out:
#              2022        2023        2024        2025        2026        2027  \
# 서울특별시  788.879167  794.469134  800.098711  805.768179  811.477821  817.227921
# 대구광역시  503.754167  508.964883  514.229497  519.548568  524.922658  530.352336
# 경기도    692.775000  708.612537  724.812136  741.382075  758.330819  775.667028
#
#              2028        2029        2030        2031  ...         2045  \
# 서울특별시  823.018767  828.850645  834.723849  840.638670  ...   927.984986
# 대구광역시  535.838177  541.380763  546.980680  552.638521  ...   638.277434
# 경기도    793.399561  811.537477  830.090045  849.066743  ...  1165.130518
#
#               2046         2047         2048         2049         2050  \
# 서울특별시   934.560651   941.182912   947.852097   954.568540   961.332576
# 대구광역시   644.879628   651.550113   658.289596   665.098791   671.978419
# 경기도    1191.766580  1219.011569  1246.879406  1275.384330  1304.540906
#
#               2051         2052         2053         2054
# ...

# %%
name='서울'
x_list=month_house.columns.to_list()
y_list=month_house.loc['서울특별시'].to_list()
_color='red'
_labels='월세'




draw_line_one_graph(name,x_list,y_list,_color,_labels)

# %%
name='대구'
x_list=month_house.columns.to_list()
y_list=month_house.loc['대구광역시'].to_list()
_color='blue'
_labels='월세'




draw_line_one_graph(name,x_list,y_list,_color,_labels)

# %%
name='경기도'
x_list=month_house.columns.to_list()
y_list=month_house.loc['경기도'].to_list()
_color='green'
_labels='월세'



draw_line_one_graph(name,x_list,y_list,_color,_labels)
