# %%
import pandas as pd
import matplotlib.pyplot as plt
import	platform
import	matplotlib.font_manager as	fm
import seaborn as sns

from graph_func import draw_bar_one_graph,draw_line_one_graph

# %% [markdown]
# ### 생활비

# %%
money=pd.read_csv('../data/money_make.csv',encoding='utf-8')

# %%
money=money.set_index("지역")

# %%
money=money.iloc[::,3:]

# %%
money
# Out:
#           2022     2023      2024      2025      2026      2027      2028  \
# 지역
# 서울특별시  9677443  9861314  10048678  10239602  10434154  10632402  10834417
# 대구광역시  7887796  8061327   8238676   8419926   8605164   8794477   8987955
# 경기도    7533972  7616845   7700630   7785336   7870974   7957554   8045087
#
#            2029      2030      2031  ...      2045      2046      2047  \
# 지역                                   ...
# 서울특별시  11040270  11250035  11463785  ...  14919916  15203394  15492258
# 대구광역시   9185690   9387775   9594306  ...  13011455  13297707  13590256
# 경기도     8133582   8223051   8313504  ...   9689468   9796052   9903808
#
#            2048      2049      2050      2051      2052      2053      2054
# 지역
# 서울특별시  15786610  16086555  16392199  16703650  17021019  17344418  17673961
# 대구광역시  13889241  14194804  14507089  14826244  15152421  15485774  15826461
# 경기도    10012749  10122889  10234240  10346816  10460630  10575696  10692028
#
# [3 rows x 33 columns]

# %%
name='서울'
x_list=money.columns.to_list()
y_list=money.loc['서울특별시'].to_list()
_color='YlOrRd'
_labels='생활비'

draw_bar_one_graph(name,x_list,y_list,_labels,_color)

# %%
name='대구'
x_list=money.columns.to_list()
y_list=money.loc['대구광역시'].to_list()
_color='YlGnBu'
_labels='생활비'

draw_bar_one_graph(name,x_list,y_list,_labels,_color)

# %%
name='경기도'
x_list=money.columns.to_list()
y_list=money.loc['경기도'].to_list()
_color='YlGn'
_labels='생활비'

draw_bar_one_graph(name,x_list,y_list,_labels,_color)

# %% [markdown]
# ### 양육비

# %%
baby=pd.read_excel('../data/양육비추정치.xlsx',index_col=0)
baby.head()
# Out:
#                2023          2024          2025          2026          2027  \
# 서울특별시  2.760235e+07  2.823240e+07  2.887683e+07  2.953596e+07  3.021014e+07
# 경기도    2.365885e+07  2.388640e+07  2.411615e+07  2.434810e+07  2.458228e+07
# 대구광역시  2.093240e+07  2.097262e+07  2.101292e+07  2.105329e+07  2.109374e+07
#
#                2028          2029          2030          2031          2032  \
# 서울특별시  3.089971e+07  3.160502e+07  3.232643e+07  3.306431e+07  3.381902e+07
# 경기도    2.481872e+07  2.505743e+07  2.529843e+07  2.554176e+07  2.578742e+07
# 대구광역시  2.113427e+07  2.117488e+07  2.121557e+07  2.125633e+07  2.129717e+07
#
#        ...          2043          2044          2045          2046  \
# 서울특별시  ...  4.334902e+07  4.433850e+07  4.535056e+07  4.638572e+07
# 경기도    ...  2.865079e+07  2.892636e+07  2.920458e+07  2.948547e+07
# 대구광역시  ...  2.175164e+07  2.179343e+07  2.183530e+07  2.187726e+07
#
#                2047          2048          2049          2050          2051  \
# ...

# %%
name='서울'
x_list=baby.columns.to_list()
y_list=baby.loc['서울특별시'].to_list()
_color='PuRd'
_labels='양육비'

draw_bar_one_graph(name,x_list,y_list,_labels,_color)

# %%
name='대구'
x_list=baby.columns.to_list()
y_list=baby.loc['대구광역시'].to_list()
_color='BuPu'
_labels='양육비'

draw_bar_one_graph(name,x_list,y_list,_labels,_color)

# %%
name='경기도'
x_list=baby.columns.to_list()
y_list=baby.loc['경기도'].to_list()
_color='Greens'
_labels='양육비'

draw_bar_one_graph(name,x_list,y_list,_labels,_color)
