# %%
import pandas as pd
import matplotlib.pyplot as plt
import	platform
import	matplotlib.font_manager as	fm
import seaborn as sns
import koreanize_matplotlib

from bargraph_func import draw_bar_one_graph

# %%
year_house=pd.read_excel('./data/연평균전세증가율.xlsx',index_col=0)
year_house.head()
# Out:
#               2022         2023         2024         2025         2026  \
# 서울특별시  6163.376984  6222.921968  6283.042223  6343.743304  6405.030825
# 대구광역시  2854.633333  2864.630847  2874.663374  2884.731036  2894.833958
# 경기도    4058.492857  4143.033384  4229.334935  4317.434191  4407.368602
#
#               2027         2028         2029         2030         2031  ...  \
# 서울특별시  6466.910451  6529.387901  6592.468952  6656.159436  6720.465239  ...
# 대구광역시  2904.972263  2915.146073  2925.355515  2935.600712  2945.881790  ...
# 경기도    4499.176393  4592.896588  4688.569024  4786.234367  4885.934130  ...
#
#               2045         2046         2047         2048         2049  \
# 서울특별시  7688.791089  7763.073247  7838.073052  7913.797438  7990.253404
# 대구광역시  3093.655542  3104.490161  3115.362724  3126.273366  3137.222218
# 경기도    6520.766721  6656.597700  6795.258108  6936.806886  7081.304198
#
#               2050         2051         2052         2053         2054
# ...

# %%
name='서울'
x_list=year_house.columns.to_list()
y_list=year_house.loc['서울특별시'].to_list()
_color='pastel'
_labels='전세'



draw_bar_one_graph(name,x_list,y_list,_labels,_color)
# Out:
# c:\Users\KDP-13\AppData\Local\anaconda3\envs\BY_YUNA_copy\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\KDP-13\AppData\Local\anaconda3\envs\BY_YUNA_copy\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\KDP-13\AppData\Local\anaconda3\envs\BY_YUNA_copy\lib\site-packages\seaborn\_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)
# ...

# %%
name='대구'
x_list=year_house.columns.to_list()
y_list=year_house.loc['대구광역시'].to_list()
_color='pastel'
_labels='전세'

draw_bar_one_graph(name,x_list,y_list,_labels,_color)
# Out:
# c:\Users\KDP-13\AppData\Local\anaconda3\envs\BY_YUNA_copy\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\KDP-13\AppData\Local\anaconda3\envs\BY_YUNA_copy\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\KDP-13\AppData\Local\anaconda3\envs\BY_YUNA_copy\lib\site-packages\seaborn\_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)
# ...

# %%
name='경기도'
x_list=year_house.columns.to_list()
y_list=year_house.loc['경기도'].to_list()
_color='green'
_labels='전세'

draw_bar_one_graph(name,x_list,y_list,_labels)
