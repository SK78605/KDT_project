# %%
import fontda
import pandas as pd
import numpy as np

# %%
file1='문해력파일/소셜_네트워크_서비스_SNS__이용_20230713193752.xlsx'
df17=pd.read_excel(file1,header=2,index_col=1)
df17.head()
# Out:
# C:\Users\KDP-13\AppData\Local\anaconda3\envs\MY_PYTHON\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#        특성별(1)  이용 한다  이용하지 않는다   트위터  페이스북  카카오스토리  네이버밴드  구글플러스  인스타그램   기타
# 특성별(2)
# 소계         전체   59.4      40.6   8.7  51.4    49.4   32.9    3.3   21.2  0.9
# 남자         성별   59.9      40.1   9.1  56.8    44.2   31.4    3.6   16.6  0.8
# 여자        NaN   59.0      41.0   8.2  45.8    54.6   34.4    3.0   26.0  1.0
# 15~19세    연령별   80.5      19.5  23.7  80.1    35.3   14.4    5.3   33.7  1.3
# 20~29세    NaN   72.3      27.7   8.8  85.1    22.5   14.7    1.1   40.6  0.6

# %%
df17=df17.iloc[3:8,3:-1]
df17
# Out:
#          트위터  페이스북  카카오스토리  네이버밴드  구글플러스  인스타그램
# 특성별(2)
# 15~19세  23.7  80.1    35.3   14.4    5.3   33.7
# 20~29세   8.8  85.1    22.5   14.7    1.1   40.6
# 30~39세   7.6  47.5    54.1   33.5    2.7   31.0
# 40~49세   4.8  36.0    58.2   48.4    4.2    5.5
# 50~59세   5.1  31.4    64.7   44.4    5.2    5.4

# %%
file2='문해력파일/주로_이용하는_SNS_계정_123순위_20230713192732.xlsx'
df22=pd.read_excel(file2,header=1,index_col=1)
df22.head()
# Out:
# C:\Users\KDP-13\AppData\Local\anaconda3\envs\MY_PYTHON\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#         구분별(1)  사례수 (명)  트위터(Twitter) (%)  페이스북(Facebook) (%)  싸이월드미니홈피 (%)  \
# 구분별(2)
# 소계          전체   5590.5              15.3                50.9           2.4
# 남           성별   2790.5              15.1                57.3           2.3
# 여          NaN   2800.0              15.4                44.5           2.6
# 만10대미만      연령      7.0               0.0                67.2           0.0
# 만10-19세    NaN    547.0              13.7                61.0           1.2
#
#          카카오스토리 (%)  인스타그램(instagram) (%)  네이버밴드 (%)  빙글 (%)  비트윈 (%)  ...  \
# 구분별(2)                                                                 ...
# 소계             33.8                  54.2       30.9     0.1      0.5  ...
# ...

# %%
df22=df22.iloc[4:9,-12:-1]
df22
# Out:
#          트위터(Twitter) (%).1  페이스북(Facebook) (%).1  싸이월드미니홈피 (%).1  \
# 구분별(2)
# 만10-19세                18.8                  59.4             1.8
# 만20-29세                26.4                  51.6             2.9
# 만30-39세                16.6                  45.6             3.4
# 만40-49세                17.8                  44.4             3.1
# 만50-59세                 8.8                  40.4             2.5
#
#          카카오스토리 (%).1  인스타그램(instagram) (%).1  네이버밴드 (%).1  빙글 (%).1  \
# 구분별(2)
# 만10-19세           9.5                    74.0         13.3       0.0
# 만20-29세          15.5                    85.1         18.7       0.1
# 만30-39세          23.8                    72.7         20.5       0.0
# 만40-49세          27.9                    59.9         34.7       0.0
# 만50-59세          40.2                    35.0         41.4       0.1
#
#          비트윈 (%).1  웨이보 (%).1  핀터레스트 (%).1  틱톡 (%).1
# 구분별(2)
# 만10-19세        0.0        0.4          0.8      23.7
# ...

# %%
df22=df22[['트위터(Twitter) (%).1','페이스북(Facebook) (%).1','카카오스토리 (%).1','인스타그램(instagram) (%).1','네이버밴드 (%).1','틱톡 (%).1']]
df22
# Out:
#          트위터(Twitter) (%).1  페이스북(Facebook) (%).1  카카오스토리 (%).1  \
# 구분별(2)
# 만10-19세                18.8                  59.4           9.5
# 만20-29세                26.4                  51.6          15.5
# 만30-39세                16.6                  45.6          23.8
# 만40-49세                17.8                  44.4          27.9
# 만50-59세                 8.8                  40.4          40.2
#
#          인스타그램(instagram) (%).1  네이버밴드 (%).1  틱톡 (%).1
# 구분별(2)
# 만10-19세                    74.0         13.3      23.7
# 만20-29세                    85.1         18.7       6.7
# 만30-39세                    72.7         20.5       4.5
# 만40-49세                    59.9         34.7       4.9
# 만50-59세                    35.0         41.4       2.5

# %%
df22=df22[['트위터(Twitter) (%).1','페이스북(Facebook) (%).1','카카오스토리 (%).1','네이버밴드 (%).1','인스타그램(instagram) (%).1','틱톡 (%).1']]
df22.columns=['트위터','페이스북','카카오스토리','네이버밴드','인스타그램','틱톡']
df22
# Out:
#           트위터  페이스북  카카오스토리  네이버밴드  인스타그램    틱톡
# 구분별(2)
# 만10-19세  18.8  59.4     9.5   13.3   74.0  23.7
# 만20-29세  26.4  51.6    15.5   18.7   85.1   6.7
# 만30-39세  16.6  45.6    23.8   20.5   72.7   4.5
# 만40-49세  17.8  44.4    27.9   34.7   59.9   4.9
# 만50-59세   8.8  40.4    40.2   41.4   35.0   2.5

# %%
df22.index=list(df17.index)
df22
# Out:
#          트위터  페이스북  카카오스토리  네이버밴드  인스타그램    틱톡
# 15~19세  18.8  59.4     9.5   13.3   74.0  23.7
# 20~29세  26.4  51.6    15.5   18.7   85.1   6.7
# 30~39세  16.6  45.6    23.8   20.5   72.7   4.5
# 40~49세  17.8  44.4    27.9   34.7   59.9   4.9
# 50~59세   8.8  40.4    40.2   41.4   35.0   2.5

# %%
df17.drop('구글플러스',axis=1,inplace=True)
# Out:
#          트위터  페이스북  카카오스토리  네이버밴드  인스타그램
# 특성별(2)
# 15~19세  23.7  80.1    35.3   14.4   33.7
# 20~29세   8.8  85.1    22.5   14.7   40.6
# 30~39세   7.6  47.5    54.1   33.5   31.0
# 40~49세   4.8  36.0    58.2   48.4    5.5
# 50~59세   5.1  31.4    64.7   44.4    5.4

# %%
df22=df22.iloc[[0,3]]
df22
# Out:
#          트위터  페이스북  카카오스토리  네이버밴드  인스타그램    틱톡
# 15~19세  18.8  59.4     9.5   13.3   74.0  23.7
# 40~49세  17.8  44.4    27.9   34.7   59.9   4.9

# %%
df22['sum']=df22.sum(axis=1)
df22
# Out:
# C:\Users\KDP-13\AppData\Local\Temp\ipykernel_12932\811364441.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df22['sum']=df22.sum(axis=1)
#          트위터  페이스북  카카오스토리  네이버밴드  인스타그램    틱톡    sum
# 15~19세  18.8  59.4     9.5   13.3   74.0  23.7  198.7
# 40~49세  17.8  44.4    27.9   34.7   59.9   4.9  189.6

# %%
df22=df22.div(df22['sum'],axis=0)
df22
# Out:
#              트위터      페이스북    카카오스토리     네이버밴드     인스타그램        틱톡  sum
# 15~19세  0.094615  0.298943  0.047811  0.066935  0.372421  0.119275  1.0
# 40~49세  0.093882  0.234177  0.147152  0.183017  0.315928  0.025844  1.0

# %%
df22=df22.apply(lambda x: round(x*100,1),axis=0)
df22
# Out:
#         트위터  페이스북  카카오스토리  네이버밴드  인스타그램    틱톡    sum
# 15~19세  9.5  29.9     4.8    6.7   37.2  11.9  100.0
# 40~49세  9.4  23.4    14.7   18.3   31.6   2.6  100.0

# %%
df22.drop('sum',axis=1,inplace=True)

# %%
df22
# Out:
#         트위터  페이스북  카카오스토리  네이버밴드  인스타그램    틱톡
# 15~19세  9.5  29.9     4.8    6.7   37.2  11.9
# 40~49세  9.4  23.4    14.7   18.3   31.6   2.6

# %%
# 그래프

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_path="malgun.ttf"
font_name=font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# %%
# plt.style.use('default')

# fig=plt.figure(figsize=(20,10))

# ax1=fig.add_subplot(1,2,1)
# ax2=fig.add_subplot(1,2,2)

# ax1.pie()

plt.figure(figsize=(12, 6))

# 첫 번째 서브플롯 생성 (15세~19세)
plt.subplot(1, 2, 1)
plt.pie(df22.loc['15~19세'], labels=df22.columns, autopct='%1.1f%%',startangle=10,colors=['#FFA07A', '#FFA500','#BDB76B','#F0E68C', '#6495ED' ,'#40E0D0',])
plt.title('청년층')

# 두 번째 서브플롯 생성 (40세~49세)
plt.subplot(1, 2, 2)
plt.pie(df22.loc['40~49세'], labels=df22.columns, autopct='%1.1f%%',startangle=10,colors=['#FFA07A', '#FFA500','#BDB76B','#F0E68C', '#6495ED' ,'#40E0D0',])
plt.title('장년층')

plt.show()
